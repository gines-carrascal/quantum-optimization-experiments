# %%
#!pip uninstall 'qiskit-aqua' -y
# !pip install --upgrade 'qiskit[visualization,optimization]'

# %%
#!pip install --upgrade 'qiskit-aqua[skquant]'

# %%
# !pip install scikit-quant

# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *

import numpy as np
import math
from docplex.mp.model import Model
from math import log

# Loading your IBM Q account(s)
provider = IBMQ.load_account()

# %%
# Quantum Aggregator Wrapper

# Import algorithms 
import grovers_search as grovers
import optim_wrapper as optimization


def aggregator(algorithm, dict_details):
    if algorithm == 'grovers':
        result = grovers.grovers_search(dict_details)
    if algorithm == 'optimizer':
        result = optimization.optimize_portfolio(dict_details)
    return result

# %% [markdown]
# # ETF Optimization (Use_case_v3)

# %% [markdown]
# ## Binary representation of integers limited to budget amount
#
# (Based on H2 Hypothesis in paper v1 and stock grouping in paper v2)
#
# $\begin{aligned}
# \min_{x \in \mathbb{N}^n}  q x^T \Sigma x - \mu^T x\\
# \end{aligned}$
#
# subject to:
#
# $\begin{aligned}
# \ \sum_{i=0}^{n} S^T x \le B,\quad x \in \mathbb{N}^n,\quad S \in \mathbb{R}^n,\quad B \in \mathbb{R} \qquad \approx_{k\to\infty}  \qquad \sum_{i=0}^{n}  ceil( \frac{k}{\overline{S}}s_i) x_i \le floor(\frac{k}{\overline{S}}B) ,\quad k \in \mathbb{R},\quad ceil(.), floor(.) \in \mathbb{N}\\
# \end{aligned}$
#
# integer variables $x_i$ bounded to:
#
# $\begin{aligned}
# 0 \le x_i \le 2^{floor(log_{2}(\frac{B}{\min_{j}{s_j}}))}-1
# \end{aligned}$
#
# where we use the following notation:
#
# - $x \in \mathbb{N}^n$ denotes the vector of integer decision variables, which indicate which assets to pick and how much ($x[i] > 0$) and which not to pick ($x[i] = 0$),
# - $y$ represents the binary decomposition of $x$
# - $\mu \in \mathbb{R}^n$ defines the expected returns for the assets,
# - $\Sigma \in \mathbb{R}^{n \times n}$ specifies the covariances between the assets,
# - $q > 0$ controls the risk appetite of the decision maker,
# - $S$ defined as the prices related to the (grouped) stocks ( $\overline{S}$ is the mean of the prices),
# - $B$ denotes the budget, i.e. the maximum amount of money to be spent purchasing assets.
# - $ceil$ is the operator that rounds up to the nearest integer
# - $floor$ is the operator that rounds down to the nearest integer
# - $k$ is a scaling factor used to tune the precision of the conversions to integer

# %%
# prepare problem instance
n = 5            # number of assets
q = 0.5          # risk factor
budget = 2250  # budget
# automatic penalty
#penalty = budget**n    # scaling of penalty term. TODO: find optimum
#print('Penalty:', penalty)

# %%
# example instance
s_real = np.array([60.04, 55.87, 139.72, 32.46, 111.07])
grouping = np.array([2, 3, 1, 4, 1])
s=grouping*s_real

print(' ̃s:', s)
# Out:
#  ̃s: [120.08 167.61 139.72 129.84 111.07]

# %%
print(s.mean())
# Out:
# 133.664

# %%
budget_bits = int(np.log2(budget/np.min(s))) #TODO: int rounds down. I guess this is just excluding high volatility solutions.
print("Budget variables per asset:", budget_bits)
# Out:
# Budget variables per asset: 4

# %%
mu = np.array([0.00290, 0.00206, 0.00033, 0.00263, -0.00012])
sigma = np.array([
    [ 0.00016, 0.00014, 0.00013, 0.00016, 0.00015],
    [ 0.00014, 0.00016, 0.00013, 0.00016, 0.00014],
    [ 0.00013, 0.00013, 0.00028, 0.00013, 0.00028],
    [ 0.00016, 0.00016, 0.00013, 0.00021, 0.00015],
    [ 0.00015, 0.00014, 0.00028, 0.00015, 0.00030]
])

# %%
# COBYLA K=7 full
# optimal function value: 0.0168
# optimal value: [12.  1.  1.  0.  2.]
initial_point = np.array([
  2.59053218,  3.07383748, -0.02830739, -3.63309921, -2.59853671, -3.20797840,
  3.33314935, -1.35133976,  3.63283071,  3.69698830, -1.23352425,  3.31862756,
  4.19931877,  1.43270108, -3.98425304, -1.57150233, -0.65458941, -0.81643120,
  4.94757565,  2.07617259,  0.07179877,  0.07303629,  2.91093525,  0.12795972,
  0.08646192, -2.99756703,  1.50578149, -1.04225831, -0.18934945,  2.62426510,
 -3.28927912,  2.79095167, -3.68730170,  2.82009121,  0.07565113, -0.15255559,
  0.03094703,  1.77756513, -1.74105261, -0.64174123, -2.06943340, -2.34060495,
 -1.07889976, -0.29862926, -0.52227792,  0.57689027, -0.29581687, -1.24656532,
  1.28653548,  2.82191423,  1.74868550, -2.30037444,  2.41060747, -0.33028446
  ])

# %%
# IMFIL K=7 circular
# optimal function value: 0.01958
# optimal value: [5. 6. 0. 4. 0.]
initial_point = np.array([
 -0.10443451,  0.15794821, -3.14159265,  3.14159265,  3.14159265,  0.08134372,
 -2.05583004,  1.96418066,  3.14159265,  2.62961285, -1.53778771,  0.15115402,
 -2.34264387,  1.09693660, -0.50155170, -1.14538203,  1.72507405,  0.47064835,
 -3.14159265, -1.89449310, -2.59013929,  0.04510715,  3.14159265, -3.14159265,
 -0.56119690,  3.13799737, -3.14159265, -3.14159265,  0.87437460, -0.33974137,
 -0.03436667,  3.14159265,  2.22961905,  3.14159265,  3.14159265,  3.14159265,
  1.80531028,  1.17137820,  3.13190004,  2.44889741,  1.21174119,  0.45292839,
 -1.03871678, -2.36174585,  3.14159265,  2.24771505, -0.74333817,  3.14159265,
  3.14159265, -3.14159265,  0.00435256, -0.24178762,  3.14159265,  0.17713373
  ])

# %%
# create docplex model
mdl = Model('portfolio_optimization')

x = mdl.integer_var_list((f'x{i}' for i in range(n)), lb=0, ub=2**budget_bits-1)

objective = mdl.sum([mu[i]*x[i] for i in range(n)])
objective -= q * mdl.sum([sigma[i,j]*x[i]*x[j] for i in range(n) for j in range(n)])
mdl.maximize(objective)

k = 7
norm = s.mean()/k
mdl.add_constraint(mdl.sum(x[i] * math.ceil(s[i]/norm) for i in range(n)) <= math.floor(budget/norm))

# import the classical optimizer
from qiskit.algorithms.optimizers import COBYLA, SLSQP, BOBYQA, IMFIL, SNOBFIT

#maxiter=2 # TODO: just for testing purposes
optim_dict = {
  "docplex_mod": mdl,
  "optimizer":SLSQP
}

# %%
# Call the aggregator with 'optimizer' as the algorithm of choice
results = aggregator('optimizer', optim_dict)
# Out:
# ### Parameters:
# {'quantum_instance': 'qasm_simulator', 'shots': 1024, 'print': True, 'solver': 'vqe', 'entanglement': 'circular', 'depth': 1, 'maxiter': 1000, 'alpha': 0.35, 'docplex_mod': <docplex.mp.model.Model object at 0x7fe66190df10>, 'optimizer': <class 'qiskit.algorithms.optimizers.slsqp.SLSQP'>}
# ### Original problem:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: portfolio_optimization
#
# Maximize
#  obj: 0.002900000000 x0 + 0.002060000000 x1 + 0.000330000000 x2
#       + 0.002630000000 x3 - 0.000120000000 x4 + [ - 0.000160000000 x0^2
#       - 0.000280000000 x0*x1 - 0.000260000000 x0*x2 - 0.000320000000 x0*x3
#       - 0.000300000000 x0*x4 - 0.000160000000 x1^2 - 0.000260000000 x1*x2
#       - 0.000320000000 x1*x3 - 0.000280000000 x1*x4 - 0.000280000000 x2^2
#       - 0.000260000000 x2*x3 - 0.000560000000 x2*x4 - 0.000210000000 x3^2
#       - 0.000300000000 x3*x4 - 0.000300000000 x4^2 ]/2
# Subject To
#  c0: 7 x0 + 9 x1 + 8 x2 + 7 x3 + 6 x4 <= 117
#
# Bounds
#        x0 <= 15
#        x1 <= 15
#        x2 <= 15
#        x3 <= 15
#        x4 <= 15
#
# Generals
#  x0 x1 x2 x3 x4
# End
#
# ### quadratic_program_to_qubo:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: portfolio_optimization
#
# Maximize
#  obj: 2618.714450000000 x0@0 + 5237.428900000000 x0@1 + 10474.857800000000 x0@2
#       + 20949.715600000000 x0@3 + 3366.916910000000 x1@0
#       + 6733.833820000000 x1@1 + 13467.667640000000 x1@2
#       + 26935.335279999999 x1@3 + 2992.813530000000 x2@0
#       + 5985.627060000000 x2@1 + 11971.254120000000 x2@2
#       + 23942.508239999999 x2@3 + 2618.714180000000 x3@0
#       + 5237.428360000000 x3@1 + 10474.856720000000 x3@2
#       + 20949.713440000000 x3@3 + 2244.609780000000 x4@0
#       + 4489.219560000000 x4@1 + 8978.439119999999 x4@2
#       + 17956.878239999998 x4@3 + 374.101650000000 c0@int_slack@0
#       + 748.203300000000 c0@int_slack@1 + 1496.406600000000 c0@int_slack@2
#       + 2992.813200000000 c0@int_slack@3 + 5985.626400000000 c0@int_slack@4
#       + 11971.252800000000 c0@int_slack@5 + 20201.489099999999 c0@int_slack@6 +
#       [ - 156.675210000000 x0@0^2 - 626.700840000000 x0@0*x0@1
#       - 1253.401680000000 x0@0*x0@2 - 2506.803360000000 x0@0*x0@3
#       - 402.878980000000 x0@0*x1@0 - 805.757960000000 x0@0*x1@1
#       - 1611.515920000000 x0@0*x1@2 - 3223.031840000000 x0@0*x1@3
#       - 358.114660000000 x0@0*x2@0 - 716.229320000000 x0@0*x2@1
#       - 1432.458640000000 x0@0*x2@2 - 2864.917280000000 x0@0*x2@3
#       - 313.350420000000 x0@0*x3@0 - 626.700840000000 x0@0*x3@1
#       - 1253.401680000000 x0@0*x3@2 - 2506.803360000000 x0@0*x3@3
#       - 268.586100000000 x0@0*x4@0 - 537.172200000000 x0@0*x4@1
#       - 1074.344400000000 x0@0*x4@2 - 2148.688800000000 x0@0*x4@3
#       - 16575.580800000000 x4@3*c0@int_slack@6 - 3.197450000000 c0@int_slack@0^2
#       - 12.789800000000 c0@int_slack@0*c0@int_slack@1
#       - 25.579600000000 c0@int_slack@0*c0@int_slack@2
#       - 51.159200000000 c0@int_slack@0*c0@int_slack@3
#       - 102.318400000000 c0@int_slack@0*c0@int_slack@4
#       - 204.636800000000 c0@int_slack@0*c0@int_slack@5
#       - 345.324600000000 c0@int_slack@0*c0@int_slack@6
#       - 12.789800000000 c0@int_slack@1^2
#       - 51.159200000000 c0@int_slack@1*c0@int_slack@2
#       - 102.318400000000 c0@int_slack@1*c0@int_slack@3
#       - 204.636800000000 c0@int_slack@1*c0@int_slack@4
#       - 409.273600000000 c0@int_slack@1*c0@int_slack@5
#       - 690.649200000000 c0@int_slack@1*c0@int_slack@6
#       - 51.159200000000 c0@int_slack@2^2
#       - 204.636800000000 c0@int_slack@2*c0@int_slack@3
#       - 409.273600000000 c0@int_slack@2*c0@int_slack@4
#       - 818.547200000000 c0@int_slack@2*c0@int_slack@5
#       - 1381.298400000000 c0@int_slack@2*c0@int_slack@6
#       - 204.636800000000 c0@int_slack@3^2
#       - 818.547200000000 c0@int_slack@3*c0@int_slack@4
#       - 1637.094400000000 c0@int_slack@3*c0@int_slack@5
#       - 2762.596800000000 c0@int_slack@3*c0@int_slack@6
#       - 818.547200000000 c0@int_slack@4^2
#       - 3274.188800000000 c0@int_slack@4*c0@int_slack@5
#       - 5525.193600000000 c0@int_slack@4*c0@int_slack@6
#       - 3274.188800000000 c0@int_slack@5^2
#       - 11050.387199999999 c0@int_slack@5*c0@int_slack@6
#       - 9323.764200000000 c0@int_slack@6^2 ]/2 -21884.946524999999
# Subject To
#
# Bounds
#  0 <= x0@0 <= 1
#  0 <= x0@1 <= 1
#  0 <= x0@2 <= 1
#  0 <= x0@3 <= 1
#  0 <= x1@0 <= 1
#  0 <= x1@1 <= 1
#  0 <= x1@2 <= 1
#  0 <= x1@3 <= 1
#  0 <= x2@0 <= 1
#  0 <= x2@1 <= 1
#  0 <= x2@2 <= 1
#  0 <= x2@3 <= 1
#  0 <= x3@0 <= 1
#  0 <= x3@1 <= 1
#  0 <= x3@2 <= 1
#  0 <= x3@3 <= 1
#  0 <= x4@0 <= 1
#  0 <= x4@1 <= 1
#  0 <= x4@2 <= 1
#  0 <= x4@3 <= 1
#  0 <= c0@int_slack@0 <= 1
#  0 <= c0@int_slack@1 <= 1
#  0 <= c0@int_slack@2 <= 1
#  0 <= c0@int_slack@3 <= 1
#  0 <= c0@int_slack@4 <= 1
#  0 <= c0@int_slack@5 <= 1
#  0 <= c0@int_slack@6 <= 1
#
# Binaries
#  x0@0 x0@1 x0@2 x0@3 x1@0 x1@1 x1@2 x1@3 x2@0 x2@1 x2@2 x2@3 x3@0 x3@1 x3@2 x3@3
#  x4@0 x4@1 x4@2 x4@3 c0@int_slack@0 c0@int_slack@1 c0@int_slack@2 c0@int_slack@3
#  c0@int_slack@4 c0@int_slack@5 c0@int_slack@6
# End
#
# Penalty: 1.598725
#
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- max_evals_grouped: 1
# -- circuit_sampler: <qiskit.opflow.converters.circuit_sampler.CircuitSampler object at 0x7fe6b141fd30>
# -- expectation: <qiskit.opflow.expectations.cvar_expectation.CVaRExpectation object at 0x7fe6b141fa30>
# -- user_valid_expectation: True
# -- include_custom: False
# -- expect_op: None
# -- quantum_instance:
# Qiskit Terra version: 0.17.0
# Backend: 'qasm_simulator (AerProvider)', with following setting:
# {'basis_gates': ['ccx', 'cp', 'cswap', 'csx', 'cu1', 'cu2', 'cu3', 'cx', 'cy', 'cz', 'delay', 'diagonal', 'h', 'id', 'initialize', 'mcphase', 'mcr', 'mcrx', 'mcry', 'mcrz', 'mcswap', 'mcsx', 'mcu1', 'mcu2', 'mcu3', 'mcx', 'mcx_gray', 'mcy', 'mcz', 'multiplexer', 'p', 'pauli', 'r', 'rx', 'rxx', 'ry', 'ryy', 'rz', 'rzx', 'rzz', 's', 'sdg', 'swap', 'sx', 't', 'tdg', 'u', 'u1', 'u2', 'u3', 'unitary', 'x', 'y', 'z', 'kraus', 'roerror', 'save_amplitudes', 'save_amplitudes_sq', 'save_density_matrix', 'save_expval', 'save_expval_var', 'save_probabilities', 'save_probabilities_dict', 'save_stabilizer', 'save_state', 'save_statevector', 'save_statevector_dict', 'set_density_matrix', 'set_stabilizer', 'set_statevector', 'snapshot'], 'coupling_map': None}
# {'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1024)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# -- optimizer: <qiskit.algorithms.optimizers.slsqp.SLSQP object at 0x7fe6b13d2be0>
# -- gradient: None
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.algorithms.minimum_eigen_solvers.vqe.VQE object at 0x7fe6b141f6d0>>
# -- initial_point: Random seed
# -- ansatz:        ┌──────────┐┌───┐     ┌───────────┐                          »
#  q_0: ─┤ RY(θ[0]) ├┤ X ├──■──┤ RY(θ[27]) ├──────────────────────────»
#        ├──────────┤└─┬─┘┌─┴─┐└───────────┘┌───────────┐             »
#  q_1: ─┤ RY(θ[1]) ├──┼──┤ X ├──────■──────┤ RY(θ[28]) ├─────────────»
#        ├──────────┤  │  └───┘    ┌─┴─┐    └───────────┘┌───────────┐»
#  q_2: ─┤ RY(θ[2]) ├──┼───────────┤ X ├──────────■──────┤ RY(θ[29]) ├»
#        ├──────────┤  │           └───┘        ┌─┴─┐    └───────────┘»
#  q_3: ─┤ RY(θ[3]) ├──┼────────────────────────┤ X ├──────────■──────»
#        ├──────────┤  │                        └───┘        ┌─┴─┐    »
#  q_4: ─┤ RY(θ[4]) ├──┼─────────────────────────────────────┤ X ├────»
#        ├──────────┤  │                                     └───┘    »
#  q_5: ─┤ RY(θ[5]) ├──┼──────────────────────────────────────────────»
#        ├──────────┤  │                                              »
#  q_6: ─┤ RY(θ[6]) ├──┼──────────────────────────────────────────────»
#        ├──────────┤  │                                              »
#  q_7: ─┤ RY(θ[7]) ├──┼──────────────────────────────────────────────»
#        ├──────────┤  │                                              »
#  q_8: ─┤ RY(θ[8]) ├──┼──────────────────────────────────────────────»
#        ├──────────┤  │                                              »
#  q_9: ─┤ RY(θ[9]) ├──┼──────────────────────────────────────────────»
#       ┌┴──────────┤  │                                              »
# q_10: ┤ RY(θ[10]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_11: ┤ RY(θ[11]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_12: ┤ RY(θ[12]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_13: ┤ RY(θ[13]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_14: ┤ RY(θ[14]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_15: ┤ RY(θ[15]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_16: ┤ RY(θ[16]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_17: ┤ RY(θ[17]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_18: ┤ RY(θ[18]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_19: ┤ RY(θ[19]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_20: ┤ RY(θ[20]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_21: ┤ RY(θ[21]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_22: ┤ RY(θ[22]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_23: ┤ RY(θ[23]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_24: ┤ RY(θ[24]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_25: ┤ RY(θ[25]) ├──┼──────────────────────────────────────────────»
#       ├───────────┤  │                                              »
# q_26: ┤ RY(θ[26]) ├──■──────────────────────────────────────────────»
#       └───────────┘                                                 »
# «                                                                       »
# « q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_2: ─────────────────────────────────────────────────────────────────»
# «      ┌───────────┐                                                    »
# « q_3: ┤ RY(θ[30]) ├────────────────────────────────────────────────────»
# «      └───────────┘┌───────────┐                                       »
# « q_4: ──────■──────┤ RY(θ[31]) ├───────────────────────────────────────»
# «          ┌─┴─┐    └───────────┘┌───────────┐                          »
# « q_5: ────┤ X ├──────────■──────┤ RY(θ[32]) ├──────────────────────────»
# «          └───┘        ┌─┴─┐    └───────────┘┌───────────┐             »
# « q_6: ─────────────────┤ X ├──────────■──────┤ RY(θ[33]) ├─────────────»
# «                       └───┘        ┌─┴─┐    └───────────┘┌───────────┐»
# « q_7: ──────────────────────────────┤ X ├──────────■──────┤ RY(θ[34]) ├»
# «                                    └───┘        ┌─┴─┐    └───────────┘»
# « q_8: ───────────────────────────────────────────┤ X ├──────────■──────»
# «                                                 └───┘        ┌─┴─┐    »
# « q_9: ────────────────────────────────────────────────────────┤ X ├────»
# «                                                              └───┘    »
# «q_10: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_11: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_12: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_13: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_14: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_15: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_16: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_17: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_18: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_19: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_20: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_21: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_22: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_23: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_24: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_25: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_26: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «                                                                       »
# « q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_2: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_3: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_4: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_5: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_6: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_7: ─────────────────────────────────────────────────────────────────»
# «      ┌───────────┐                                                    »
# « q_8: ┤ RY(θ[35]) ├────────────────────────────────────────────────────»
# «      └───────────┘┌───────────┐                                       »
# « q_9: ──────■──────┤ RY(θ[36]) ├───────────────────────────────────────»
# «          ┌─┴─┐    └───────────┘┌───────────┐                          »
# «q_10: ────┤ X ├──────────■──────┤ RY(θ[37]) ├──────────────────────────»
# «          └───┘        ┌─┴─┐    └───────────┘┌───────────┐             »
# «q_11: ─────────────────┤ X ├──────────■──────┤ RY(θ[38]) ├─────────────»
# «                       └───┘        ┌─┴─┐    └───────────┘┌───────────┐»
# «q_12: ──────────────────────────────┤ X ├──────────■──────┤ RY(θ[39]) ├»
# «                                    └───┘        ┌─┴─┐    └───────────┘»
# «q_13: ───────────────────────────────────────────┤ X ├──────────■──────»
# «                                                 └───┘        ┌─┴─┐    »
# «q_14: ────────────────────────────────────────────────────────┤ X ├────»
# «                                                              └───┘    »
# «q_15: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_16: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_17: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_18: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_19: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_20: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_21: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_22: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_23: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_24: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_25: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_26: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «                                                                       »
# « q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_2: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_3: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_4: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_5: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_6: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_7: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_8: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_9: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_10: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_11: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_12: ─────────────────────────────────────────────────────────────────»
# «      ┌───────────┐                                                    »
# «q_13: ┤ RY(θ[40]) ├────────────────────────────────────────────────────»
# «      └───────────┘┌───────────┐                                       »
# «q_14: ──────■──────┤ RY(θ[41]) ├───────────────────────────────────────»
# «          ┌─┴─┐    └───────────┘┌───────────┐                          »
# «q_15: ────┤ X ├──────────■──────┤ RY(θ[42]) ├──────────────────────────»
# «          └───┘        ┌─┴─┐    └───────────┘┌───────────┐             »
# «q_16: ─────────────────┤ X ├──────────■──────┤ RY(θ[43]) ├─────────────»
# «                       └───┘        ┌─┴─┐    └───────────┘┌───────────┐»
# «q_17: ──────────────────────────────┤ X ├──────────■──────┤ RY(θ[44]) ├»
# «                                    └───┘        ┌─┴─┐    └───────────┘»
# «q_18: ───────────────────────────────────────────┤ X ├──────────■──────»
# «                                                 └───┘        ┌─┴─┐    »
# «q_19: ────────────────────────────────────────────────────────┤ X ├────»
# «                                                              └───┘    »
# «q_20: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_21: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_22: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_23: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_24: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_25: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_26: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «                                                                       »
# « q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_2: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_3: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_4: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_5: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_6: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_7: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_8: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# « q_9: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_10: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_11: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_12: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_13: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_14: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_15: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_16: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_17: ─────────────────────────────────────────────────────────────────»
# «      ┌───────────┐                                                    »
# «q_18: ┤ RY(θ[45]) ├────────────────────────────────────────────────────»
# «      └───────────┘┌───────────┐                                       »
# «q_19: ──────■──────┤ RY(θ[46]) ├───────────────────────────────────────»
# «          ┌─┴─┐    └───────────┘┌───────────┐                          »
# «q_20: ────┤ X ├──────────■──────┤ RY(θ[47]) ├──────────────────────────»
# «          └───┘        ┌─┴─┐    └───────────┘┌───────────┐             »
# «q_21: ─────────────────┤ X ├──────────■──────┤ RY(θ[48]) ├─────────────»
# «                       └───┘        ┌─┴─┐    └───────────┘┌───────────┐»
# «q_22: ──────────────────────────────┤ X ├──────────■──────┤ RY(θ[49]) ├»
# «                                    └───┘        ┌─┴─┐    └───────────┘»
# «q_23: ───────────────────────────────────────────┤ X ├──────────■──────»
# «                                                 └───┘        ┌─┴─┐    »
# «q_24: ────────────────────────────────────────────────────────┤ X ├────»
# «                                                              └───┘    »
# «q_25: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «q_26: ─────────────────────────────────────────────────────────────────»
# «                                                                       »
# «
# « q_0: ───────────────────────────────────────
# «
# « q_1: ───────────────────────────────────────
# «
# « q_2: ───────────────────────────────────────
# «
# « q_3: ───────────────────────────────────────
# «
# « q_4: ───────────────────────────────────────
# «
# « q_5: ───────────────────────────────────────
# «
# « q_6: ───────────────────────────────────────
# «
# « q_7: ───────────────────────────────────────
# «
# « q_8: ───────────────────────────────────────
# «
# « q_9: ───────────────────────────────────────
# «
# «q_10: ───────────────────────────────────────
# «
# «q_11: ───────────────────────────────────────
# «
# «q_12: ───────────────────────────────────────
# «
# «q_13: ───────────────────────────────────────
# «
# «q_14: ───────────────────────────────────────
# «
# «q_15: ───────────────────────────────────────
# «
# «q_16: ───────────────────────────────────────
# «
# «q_17: ───────────────────────────────────────
# «
# «q_18: ───────────────────────────────────────
# «
# «q_19: ───────────────────────────────────────
# «
# «q_20: ───────────────────────────────────────
# «
# «q_21: ───────────────────────────────────────
# «
# «q_22: ───────────────────────────────────────
# «      ┌───────────┐
# «q_23: ┤ RY(θ[50]) ├──────────────────────────
# «      └───────────┘┌───────────┐
# «q_24: ──────■──────┤ RY(θ[51]) ├─────────────
# «          ┌─┴─┐    └───────────┘┌───────────┐
# «q_25: ────┤ X ├──────────■──────┤ RY(θ[52]) ├
# «          └───┘        ┌─┴─┐    ├───────────┤
# «q_26: ─────────────────┤ X ├────┤ RY(θ[53]) ├
# «                       └───┘    └───────────┘
# -- ansatz_params: [ParameterVectorElement(θ[0]), ParameterVectorElement(θ[10]), ParameterVectorElement(θ[11]), ParameterVectorElement(θ[12]), ParameterVectorElement(θ[13]), ParameterVectorElement(θ[14]), ParameterVectorElement(θ[15]), ParameterVectorElement(θ[16]), ParameterVectorElement(θ[17]), ParameterVectorElement(θ[18]), ParameterVectorElement(θ[19]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[20]), ParameterVectorElement(θ[21]), ParameterVectorElement(θ[22]), ParameterVectorElement(θ[23]), ParameterVectorElement(θ[24]), ParameterVectorElement(θ[25]), ParameterVectorElement(θ[26]), ParameterVectorElement(θ[27]), ParameterVectorElement(θ[28]), ParameterVectorElement(θ[29]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[30]), ParameterVectorElement(θ[31]), ParameterVectorElement(θ[32]), ParameterVectorElement(θ[33]), ParameterVectorElement(θ[34]), ParameterVectorElement(θ[35]), ParameterVectorElement(θ[36]), ParameterVectorElement(θ[37]), ParameterVectorElement(θ[38]), ParameterVectorElement(θ[39]), ParameterVectorElement(θ[3]), ParameterVectorElement(θ[40]), ParameterVectorElement(θ[41]), ParameterVectorElement(θ[42]), ParameterVectorElement(θ[43]), ParameterVectorElement(θ[44]), ParameterVectorElement(θ[45]), ParameterVectorElement(θ[46]), ParameterVectorElement(θ[47]), ParameterVectorElement(θ[48]), ParameterVectorElement(θ[49]), ParameterVectorElement(θ[4]), ParameterVectorElement(θ[50]), ParameterVectorElement(θ[51]), ParameterVectorElement(θ[52]), ParameterVectorElement(θ[53]), ParameterVectorElement(θ[5]), ParameterVectorElement(θ[6]), ParameterVectorElement(θ[7]), ParameterVectorElement(θ[8]), ParameterVectorElement(θ[9])]
# -- parameterized_circuits: None
# -- ret: OrderedDict([   ('aux_operator_eigenvalues', None),
#                 ('cost_function_evals', None),
#                 ('eigenstate', None),
#                 ('eigenvalue', None),
#                 ('optimal_parameters', None),
#                 ('optimal_point', None),
#                 ('optimal_value', None),
#                 ('optimizer_evals', None),
#                 ('optimizer_time', None)])
# -- eval_time: None
# -- callback: None
# -- eval_count: 0
# ===============================================================
# NLocal: RealAmplitudes
# -- base_name: nlocal
# ...
# -- qubits: [Qubit(QuantumRegister(27, 'q'), 0), Qubit(QuantumRegister(27, 'q'), 1), Qubit(QuantumRegister(27, 'q'), 2), Qubit(QuantumRegister(27, 'q'), 3), Qubit(QuantumRegister(27, 'q'), 4), Qubit(QuantumRegister(27, 'q'), 5), Qubit(QuantumRegister(27, 'q'), 6), Qubit(QuantumRegister(27, 'q'), 7), Qubit(QuantumRegister(27, 'q'), 8), Qubit(QuantumRegister(27, 'q'), 9), Qubit(QuantumRegister(27, 'q'), 10), Qubit(QuantumRegister(27, 'q'), 11), Qubit(QuantumRegister(27, 'q'), 12), Qubit(QuantumRegister(27, 'q'), 13), Qubit(QuantumRegister(27, 'q'), 14), Qubit(QuantumRegister(27, 'q'), 15), Qubit(QuantumRegister(27, 'q'), 16), Qubit(QuantumRegister(27, 'q'), 17), Qubit(QuantumRegister(27, 'q'), 18), Qubit(QuantumRegister(27, 'q'), 19), Qubit(QuantumRegister(27, 'q'), 20), Qubit(QuantumRegister(27, 'q'), 21), Qubit(QuantumRegister(27, 'q'), 22), Qubit(QuantumRegister(27, 'q'), 23), Qubit(QuantumRegister(27, 'q'), 24), Qubit(QuantumRegister(27, 'q'), 25), Qubit(QuantumRegister(27, 'q'), 26)]
# -- qubit_set: {Qubit(QuantumRegister(27, 'q'), 6), Qubit(QuantumRegister(27, 'q'), 12), Qubit(QuantumRegister(27, 'q'), 15), Qubit(QuantumRegister(27, 'q'), 21), Qubit(QuantumRegister(27, 'q'), 18), Qubit(QuantumRegister(27, 'q'), 24), Qubit(QuantumRegister(27, 'q'), 2), Qubit(QuantumRegister(27, 'q'), 5), Qubit(QuantumRegister(27, 'q'), 11), Qubit(QuantumRegister(27, 'q'), 8), Qubit(QuantumRegister(27, 'q'), 14), Qubit(QuantumRegister(27, 'q'), 17), Qubit(QuantumRegister(27, 'q'), 23), Qubit(QuantumRegister(27, 'q'), 20), Qubit(QuantumRegister(27, 'q'), 26), Qubit(QuantumRegister(27, 'q'), 4), Qubit(QuantumRegister(27, 'q'), 1), Qubit(QuantumRegister(27, 'q'), 7), Qubit(QuantumRegister(27, 'q'), 10), Qubit(QuantumRegister(27, 'q'), 16), Qubit(QuantumRegister(27, 'q'), 13), Qubit(QuantumRegister(27, 'q'), 19), Qubit(QuantumRegister(27, 'q'), 22), Qubit(QuantumRegister(27, 'q'), 25), Qubit(QuantumRegister(27, 'q'), 0), Qubit(QuantumRegister(27, 'q'), 3), Qubit(QuantumRegister(27, 'q'), 9)}
# -- parameter_table: ParameterTable({ParameterVectorElement(θ[0]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe6b141fdf0>, 0)], ParameterVectorElement(θ[1]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c593d0>, 0)], ParameterVectorElement(θ[2]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59400>, 0)], ParameterVectorElement(θ[3]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59430>, 0)], ParameterVectorElement(θ[4]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59460>, 0)], ParameterVectorElement(θ[5]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59490>, 0)], ParameterVectorElement(θ[6]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c594c0>, 0)], ParameterVectorElement(θ[7]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c594f0>, 0)], ParameterVectorElement(θ[8]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59520>, 0)], ParameterVectorElement(θ[9]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59550>, 0)], ParameterVectorElement(θ[10]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59580>, 0)], ParameterVectorElement(θ[11]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c595b0>, 0)], ParameterVectorElement(θ[12]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c595e0>, 0)], ParameterVectorElement(θ[13]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59610>, 0)], ParameterVectorElement(θ[14]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59640>, 0)], ParameterVectorElement(θ[15]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59670>, 0)], ParameterVectorElement(θ[16]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c596a0>, 0)], ParameterVectorElement(θ[17]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c596d0>, 0)], ParameterVectorElement(θ[18]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59700>, 0)], ParameterVectorElement(θ[19]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59730>, 0)], ParameterVectorElement(θ[20]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59760>, 0)], ParameterVectorElement(θ[21]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59790>, 0)], ParameterVectorElement(θ[22]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c597c0>, 0)], ParameterVectorElement(θ[23]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c597f0>, 0)], ParameterVectorElement(θ[24]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59820>, 0)], ParameterVectorElement(θ[25]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59850>, 0)], ParameterVectorElement(θ[26]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59880>, 0)], ParameterVectorElement(θ[27]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c59ca0>, 0)], ParameterVectorElement(θ[28]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5dd30>, 0)], ParameterVectorElement(θ[29]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5dd60>, 0)], ParameterVectorElement(θ[30]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5dd90>, 0)], ParameterVectorElement(θ[31]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5ddc0>, 0)], ParameterVectorElement(θ[32]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5ddf0>, 0)], ParameterVectorElement(θ[33]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe680c5de20>, 0)], ParameterVectorElement(θ[34]): [(<qiskit.circuit.library.standard_gates.ry.RYGate object at 0x7fe6 ...
# -- clbits: []
# -- clbit_set: set()
# -- ancillas: []
# -- calibrations: defaultdict(<class 'dict'>, {})
# -- parameters: [ParameterVectorElement(θ[0]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[3]), ParameterVectorElement(θ[4]), ParameterVectorElement(θ[5]), ParameterVectorElement(θ[6]), ParameterVectorElement(θ[7]), ParameterVectorElement(θ[8]), ParameterVectorElement(θ[9]), ParameterVectorElement(θ[10]), ParameterVectorElement(θ[11]), ParameterVectorElement(θ[12]), ParameterVectorElement(θ[13]), ParameterVectorElement(θ[14]), ParameterVectorElement(θ[15]), ParameterVectorElement(θ[16]), ParameterVectorElement(θ[17]), ParameterVectorElement(θ[18]), ParameterVectorElement(θ[19]), ParameterVectorElement(θ[20]), ParameterVectorElement(θ[21]), ParameterVectorElement(θ[22]), ParameterVectorElement(θ[23]), ParameterVectorElement(θ[24]), ParameterVectorElement(θ[25]), ParameterVectorElement(θ[26]), ParameterVectorElement(θ[27]), ParameterVectorElement(θ[28]), ParameterVectorElement(θ[29]), ParameterVectorElement(θ[30]), ParameterVectorElement(θ[31]), ParameterVectorElement(θ[32]), ParameterVectorElement(θ[33]), ParameterVectorElement(θ[34]), ParameterVectorElement(θ[35]), ParameterVectorElement(θ[36]), ParameterVectorElement(θ[37]), ParameterVectorElement(θ[38]), ParameterVectorElement(θ[39]), ParameterVectorElement(θ[40]), ParameterVectorElement(θ[41]), ParameterVectorElement(θ[42]), ParameterVectorElement(θ[43]), ParameterVectorElement(θ[44]), ParameterVectorElement(θ[45]), ParameterVectorElement(θ[46]), ParameterVectorElement(θ[47]), ParameterVectorElement(θ[48]), ParameterVectorElement(θ[49]), ParameterVectorElement(θ[50]), ParameterVectorElement(θ[51]), ParameterVectorElement(θ[52]), ParameterVectorElement(θ[53])]
# -- layout: None
# -- global_phase: 0
# -- metadata: None
# -- cregs: []
# -- num_qubits: 27
# -- insert_barriers: False
# -- reps: 1
# -- entanglement_blocks: [<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fe6b13ed6a0>]
# -- rotation_blocks: [<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fe6b13ed880>]
# -- prepended_blocks: []
# -- prepended_entanglement: []
# -- appended_blocks: []
# -- appended_entanglement: []
# -- entanglement: circular
# -- entangler_maps: None
# -- ordered_parameters: θ, ['θ[0]', 'θ[1]', 'θ[2]', 'θ[3]', 'θ[4]', 'θ[5]', 'θ[6]', 'θ[7]', 'θ[8]', 'θ[9]', 'θ[10]', 'θ[11]', 'θ[12]', 'θ[13]', 'θ[14]', 'θ[15]', 'θ[16]', 'θ[17]', 'θ[18]', 'θ[19]', 'θ[20]', 'θ[21]', 'θ[22]', 'θ[23]', 'θ[24]', 'θ[25]', 'θ[26]', 'θ[27]', 'θ[28]', 'θ[29]', 'θ[30]', 'θ[31]', 'θ[32]', 'θ[33]', 'θ[34]', 'θ[35]', 'θ[36]', 'θ[37]', 'θ[38]', 'θ[39]', 'θ[40]', 'θ[41]', 'θ[42]', 'θ[43]', 'θ[44]', 'θ[45]', 'θ[46]', 'θ[47]', 'θ[48]', 'θ[49]', 'θ[50]', 'θ[51]', 'θ[52]', 'θ[53]']
# -- overwrite_block_parameters: True
# -- skip_final_rotation_layer: False
# -- skip_unentangled_qubits: False
# -- initial_state: None
# -- initial_state_circuit: None
# -- bounds: None
# ===============================================================
# Optimizer: SLSQP
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxiter': 1000, 'disp': True, 'ftol': 1e-06, 'eps': 1.4901161193847656e-08}
# -- max_evals_grouped: 1
# -- tol: None
# ===============================================================
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-d303094381ec> in <module>
#       1 # Call the aggregator with 'optimizer' as the algorithm of choice
# ----> 2 results = aggregator('optimizer', optim_dict)
#
# <ipython-input-2-52f62a9411c8> in aggregator(algorithm, dict_details)
#      10         result = grovers.grovers_search(dict_details)
#      11     if algorithm == 'optimizer':
# ---> 12         result = optimization.optimize_portfolio(dict_details)
#      13     return result
#
# ~/git/quantum-optimization-experiments/optim_wrapper.py in optimize_portfolio(d)
#     147         # solve problem
#     148         t_00 = time.perf_counter()
# --> 149         results = opt_alg.solve(qp1)
#     150         t_0 = time.perf_counter() - t_00
#     151         result['computational_time'] = t_0
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit_optimization/algorithms/minimum_eigen_optimizer.py in solve(self, problem)
#     170         operator, offset = problem_.to_ising()
#     171
# --> 172         return self._solve_internal(operator, offset, problem_, problem)
#     173
#     174     def _solve_internal(self,
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit_optimization/algorithms/minimum_eigen_optimizer.py in _solve_internal(self, operator, offset, converted_problem, original_problem)
#     184
#     185             # approximate ground state of operator using min eigen solver
# --> 186             eigen_result = self._min_eigen_solver.compute_minimum_eigenvalue(operator)
#     187             # analyze results
#     188             fval = None
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     409                     backend=self._quantum_instance)
#     410         if not self._expect_op:
# --> 411             self._expect_op = self.construct_expectation(self._ansatz_params, operator)
#     412         vqresult = self.find_minimum(initial_point=self.initial_point,
#     413                                      ansatz=self.ansatz,
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in construct_expectation(self, parameter, operator)
#     297                                  'can be chosen automatically.')
#     298
# --> 299         observable_meas = self.expectation.convert(StateFn(operator, is_measurement=True))
#     300         ansatz_circuit_op = CircuitStateFn(wave_function)
#     301         return observable_meas.compose(ansatz_circuit_op).reduce()
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/expectations/cvar_expectation.py in convert(self, operator)
#      90             return operator
#      91
# ---> 92         return replace_with_cvar(expectation)
#      93
#      94     def compute_variance(self, exp_op: OperatorBase) -> Union[list, float]:
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/expectations/cvar_expectation.py in replace_with_cvar(operator)
#      87                 return CVaRMeasurement(operator.primitive, alpha=self.alpha)
#      88             elif isinstance(operator, ListOp):
# ---> 89                 return operator.traverse(replace_with_cvar)
#      90             return operator
#      91
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/list_ops/list_op.py in traverse(self, convert_fn, coeff)
#     201             return ListOp([convert_fn(op) for op in self.oplist],
#     202                           **self._state(coeff=coeff))
# --> 203         return self.__class__([convert_fn(op) for op in self.oplist],
#     204                               coeff=coeff, abelian=self.abelian)
#     205
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/list_ops/list_op.py in <listcomp>(.0)
#     201             return ListOp([convert_fn(op) for op in self.oplist],
#     202                           **self._state(coeff=coeff))
# --> 203         return self.__class__([convert_fn(op) for op in self.oplist],
#     204                               coeff=coeff, abelian=self.abelian)
#     205
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/expectations/cvar_expectation.py in replace_with_cvar(operator)
#      85         def replace_with_cvar(operator):
#      86             if isinstance(operator, OperatorStateFn) and operator.is_measurement:
# ---> 87                 return CVaRMeasurement(operator.primitive, alpha=self.alpha)
#      88             elif isinstance(operator, ListOp):
#      89                 return operator.traverse(replace_with_cvar)
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/state_fns/cvar_measurement.py in __init__(self, primitive, alpha, coeff)
#      69         self._alpha = alpha
#      70
# ---> 71         if not _check_is_diagonal(primitive):
#      72             raise OpflowError('Input operator to CVaRMeasurement must be diagonal, but is not:',
#      73                               str(primitive))
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/state_fns/cvar_measurement.py in _check_is_diagonal(operator)
#     371
#     372     # cannot efficiently check if a operator is diagonal, converting to matrix
# --> 373     matrix = operator.to_matrix()
#     374
#     375     if np.all(matrix == np.diag(np.diagonal(matrix))):
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/qiskit/opflow/primitive_ops/pauli_sum_op.py in to_matrix(self, massive)
#     240         if isinstance(self.coeff, ParameterExpression):
#     241             return (self.primitive.to_matrix(sparse=True)).toarray() * self.coeff
# --> 242         return (self.primitive.to_matrix(sparse=True) * self.coeff).toarray()
#     243
#     244     def __str__(self) -> str:
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/scipy/sparse/compressed.py in toarray(self, order, out)
#    1023         if out is None and order is None:
#    1024             order = self._swap('cf')[0]
# -> 1025         out = self._process_toarray_args(order, out)
#    1026         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1027             raise ValueError('Output array must be C or F contiguous')
#
# /opt/anaconda3/envs/QISKIT_BN/lib/python3.8/site-packages/scipy/sparse/base.py in _process_toarray_args(self, order, out)
#    1183             return out
#    1184         else:
# -> 1185             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1186
#    1187
#
# MemoryError: Unable to allocate 256. PiB for an array with shape (134217728, 134217728) and data type complex128

# %%
results['result'].variables_dict

# %%
print()
print('Integer results (amount of groups of stocks): x')
x_val = [results['result'].variables_dict[f'x{i}'] for i in range(5)]
print(x_val)

print()
print('Amount of individual stock:')
x_ind = grouping*x_val
print(x_ind)

print()
print('Amount invest in each stock:')
invest = s_real*x_ind
print(invest)

print()
print('Total invest:')
print(invest.sum())

# %%
import qiskit.tools.jupyter
# %qiskit_version_table

# %%
qiskit.__qiskit_version__

# %%
import qiskit.tools.jupyter
# %qiskit_version_table

# %%
qiskit.__qiskit_version__
